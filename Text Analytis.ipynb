# %%
from bs4 import BeautifulSoup 
import urllib.request

# %%
url = "https://www.thehindu.com"

# %%
oururl = urllib.request.urlopen(url)

# %%
soup = BeautifulSoup(oururl,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    The Hindu: Breaking News, India News, Sports News and Live Updates
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Breaking News, India News, Sports News and Live Updates" name="title">
#    <meta content="homepage" name="atdlayout">
#     <meta content="Today's News Headlines, Breaking News &amp; Latest News from India and World, News from Politics, Sports, Business, Arts and Entertainment" name="description">
#      <meta content="Breaking News, India News, Sports News and Live Updates" name="twitter:title"/>
#      <meta content="Today's News Headlines, Breaking News &amp; Latest News from India and World, News from Politics, Sports, Business, Arts and Entertainment" name="twitter:description"/>
# ...

# %% [markdown]
# https://www.thehindu.com/news/national/spyware-attack-via-whatsapp-activists-say-they-will-move-court/article29846213.ece?homepage=true

# %%
url_1 = "https://www.thehindu.com/news/national/spyware-attack-via-whatsapp-activists-say-they-will-move-court/article29846213.ece?homepage=true"

# %%
newurl = urllib.request.urlopen(url_1)

# %%
soup_1 = BeautifulSoup(newurl,'html.parser')

# %%
print(soup_1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Spyware attack via WhatsApp: Activists say they will move court - The Hindu
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Spyware attack via WhatsApp: Activists say they will move court" name="title">
#    <meta content="articlepage" name="atdlayout">
#     <meta content="Among the individuals targeted in Maharashtra are lawyer Nihalsing Rathod, academic Anand Teltumbde, activist of the Kabir Kala Manch Rupali Jadhav, Dalit activist Vivek Sundara, former Ph.D student of Tata Institute of Social Sciences Ajmal Khan, human rights lawyer Jagdish Meshram, and Dalit activist Veera Sathidar, who also acted in the film Court." name="description">
# ...

# %%
# Out:
# 1

# %%
news = []

for i in soup_1.find_all('div', {'id':'content-body-14269002-29846213'}): 
    text = i.find_all('p')
    print(text)
    news.append(text)
    
listToStr = ' '.join([str(elem) for elem in news])
# Out:
# [<p>The <strong><a href="https://www.thehindu.com/news/national/israeli-spyware-used-to-target-indian-journalists-human-rights-activists-whatsapp/article29839239.ece" target="_blank">spyware attack on WhatsApp users</a></strong> targeted over a dozen civil rights activists, lawyers and journalists in Maharashtra, Chhattisgarh and Goa.</p>, <p>The activists connected to the Bhima-Koregaon and Elgar Parishad cases said they would be approaching the court for action, while the Nationalist Congress Party demanded that Maharashtra Governor Bhagat Singh Koshyari institute a probe. Among the individuals targeted in Maharashtra are lawyer Nihalsing Rathod, academic Anand Teltumbde, activist of the Kabir Kala Manch Rupali Jadhav, Dalit activist Vivek Sundara, former Ph.D student of Tata Institute of Social Sciences (TISS) Ajmal Khan, human rights lawyer Jagdish Meshram, and Dalit activist Veera Sathidar, who also acted in the film <em>Court.</em></p>, <p>Senior officials from the Maharashtra 
# ...

# %%
len(news)
# Out:
# 1

# %%
import re

# %%
pattern = re.compile("<.*?>")
#pattern_1 = re.compile("^\s.*.*")
news_clean = re.sub(pattern,"", listToStr)
news_clean_1 = re.sub("\W", " ", news_clean)
print(news_clean)
# Out:
# [The spyware attack on WhatsApp users targeted over a dozen civil rights activists, lawyers and journalists in Maharashtra, Chhattisgarh and Goa., The activists connected to the Bhima-Koregaon and Elgar Parishad cases said they would be approaching the court for action, while the Nationalist Congress Party demanded that Maharashtra Governor Bhagat Singh Koshyari institute a probe. Among the individuals targeted in Maharashtra are lawyer Nihalsing Rathod, academic Anand Teltumbde, activist of the Kabir Kala Manch Rupali Jadhav, Dalit activist Vivek Sundara, former Ph.D student of Tata Institute of Social Sciences (TISS) Ajmal Khan, human rights lawyer Jagdish Meshram, and Dalit activist Veera Sathidar, who also acted in the film Court., Senior officials from the Maharashtra Home Department said the government is not in the know of any activity involving private or government organisations snooping on activists and lawyers in the state. The process of phone tapping is carried out throu
# ...

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
#sentences = sent_tokenize(news_clean)
#tokenised_words = word_tokenize(news_clean_1)



text = "It’s the sunniest day this week. Yesterday was cloudy. Anna is in Berlin today. Sunny Berlin! Berlin is always exciting! To be or not to be."

token = word_tokenize(text)

# %%
print(token)

from nltk.corpus import stopwords
words_1_clean = []
stopWords = set(stopwords.words('english'))
for words in token:
    if words not in stopWords:
        words_1_clean.append(words)
        
print(words_1_clean)

from nltk.stem import PorterStemmer 
ps = PorterStemmer() 

for w in words_1_clean: 
    print(w, " : ", ps.stem(w))
# Out:
# ['It', '’', 's', 'the', 'sunniest', 'day', 'this', 'week', '.', 'Yesterday', 'was', 'cloudy', '.', 'Anna', 'is', 'in', 'Berlin', 'today', '.', 'Sunny', 'Berlin', '!', 'Berlin', 'is', 'always', 'exciting', '!', 'To', 'be', 'or', 'not', 'to', 'be', '.']
# ['It', '’', 'sunniest', 'day', 'week', '.', 'Yesterday', 'cloudy', '.', 'Anna', 'Berlin', 'today', '.', 'Sunny', 'Berlin', '!', 'Berlin', 'always', 'exciting', '!', 'To', '.']
# It  :  It
# ’  :  ’
# sunniest  :  sunniest
# day  :  day
# week  :  week
# .  :  .
# Yesterday  :  yesterday
# cloudy  :  cloudi
# .  :  .
# Anna  :  anna
# Berlin  :  berlin
# today  :  today
# .  :  .
# Sunny  :  sunni
# Berlin  :  berlin
# !  :  !
# Berlin  :  berlin
# always  :  alway
# exciting  :  excit
# !  :  !
# To  :  To
# .  :  .

# %%
len(tokenised_words)
# Out:
# 520

# %%
len(sentences)
# Out:
# 14

# %%
print(sentences[0])
# Out:
# [The spyware attack on WhatsApp users targeted over a dozen civil rights activists, lawyers and journalists in Maharashtra, Chhattisgarh and Goa., The activists connected to the Bhima-Koregaon and Elgar Parishad cases said they would be approaching the court for action, while the Nationalist Congress Party demanded that Maharashtra Governor Bhagat Singh Koshyari institute a probe.

# %%
from nltk import pos_tag
pos_tags = nltk.pos_tag(tokenised_words)
tags =[]

for item in pos_tags:
    tags.append(item[1])
print(tags)
# Out:
# ['DT', 'JJ', 'NN', 'IN', 'NNP', 'NNS', 'VBD', 'IN', 'DT', 'NN', 'JJ', 'NNS', 'VBZ', 'NNS', 'CC', 'NNS', 'IN', 'NNP', 'NNP', 'CC', 'NNP', 'DT', 'NNS', 'VBD', 'TO', 'DT', 'NNP', 'NNP', 'CC', 'NNP', 'NNP', 'NNS', 'VBD', 'PRP', 'MD', 'VB', 'VBG', 'DT', 'NN', 'IN', 'NN', 'IN', 'DT', 'NNP', 'NNP', 'NNP', 'VBD', 'IN', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'DT', 'NN', 'IN', 'DT', 'NNS', 'VBN', 'IN', 'NNP', 'VBP', 'NN', 'NNP', 'NNP', 'JJ', 'NNP', 'NNP', 'NN', 'IN', 'DT', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NN', 'NNP', 'NNP', 'JJ', 'NNP', 'NNP', 'NN', 'IN', 'NNP', 'NNP', 'IN', 'NNP', 'NNPS', 'NNP', 'NNP', 'NNP', 'JJ', 'NNS', 'NN', 'JJ', 'NNP', 'CC', 'NNP', 'VBP', 'NNP', 'NNP', 'WP', 'RB', 'VBD', 'IN', 'DT', 'NN', 'NNP', 'NNP', 'NNS', 'IN', 'DT', 'NNP', 'NNP', 'NNP', 'VBD', 'DT', 'NN', 'VBZ', 'RB', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', 'VBG', 'JJ', 'CC', 'NN', 'NNS', 'VBG', 'IN', 'NNS', 'CC', 'NNS', 'IN', 'DT', 'NN', 'DT', 'NN', 'IN', 'NN', 'NN', 'VBZ', 'VBN', 'RP', 'IN', 'DT', 'NN', '
# ...

# %%
import pandas as pd
data = {'tokens':tokenised_words, 'POS Tags':tags, 'Language': "en"}
pdf = pd.DataFrame(data)
print(pdf)
# Out:
#            tokens POS Tags Language
# 0             The       DT       en
# 1         spyware       JJ       en
# 2          attack       NN       en
# 3              on       IN       en
# 4        WhatsApp      NNP       en
# 5           users      NNS       en
# 6        targeted      VBD       en
# 7            over       IN       en
# 8               a       DT       en
# 9           dozen       NN       en
# 10          civil       JJ       en
# 11         rights      NNS       en
# 12      activists      VBZ       en
# 13        lawyers      NNS       en
# 14            and       CC       en
# 15    journalists      NNS       en
# 16             in       IN       en
# 17    Maharashtra      NNP       en
# 18   Chhattisgarh      NNP       en
# 19            and       CC       en
# 20            Goa      NNP       en
# 21            The       DT       en
# 22      activists      NNS       en
# 23      connected      VBD       en
# 24             to       TO       en
# ...

# %%
import collections
import pprint

word_count = collections.Counter(tokenised_words)
pprint.pprint(word_count)
# Out:
# Counter({'the': 25,
#          'of': 16,
#          'said': 13,
#          'and': 11,
#          'in': 10,
#          'a': 9,
#          'to': 7,
#          'they': 7,
#          'that': 7,
#          'is': 7,
#          'activists': 6,
#          'with': 6,
#          'I': 6,
#          'The': 5,
#          'spyware': 5,
#          'WhatsApp': 5,
#          'targeted': 5,
#          'Maharashtra': 5,
#          'also': 5,
#          'was': 5,
#          'have': 5,
#          'been': 5,
#          'be': 4,
#          'activist': 4,
#          'who': 4,
#          'from': 4,
#          'this': 4,
#          'were': 4,
#          'based': 4,
#          'calls': 4,
#          'on': 3,
#          'while': 3,
#          'lawyer': 3,
#          'Dalit': 3,
#          'phone': 3,
#          'senior': 3,
#          'at': 3,
#          'as': 3,
#          'Government': 3,
#          'get': 3,
#          'movements': 3,
#          'she': 3,
#          'rights': 2,
#          'lawyers': 2,
# ...

# %%
new_words ={}
for keys,values in word_count.items():
    if values < 7:
        new_words[keys] = values
        
    
#pprint.pprint(new_words) 

words_1 = []

for keys in new_words.keys():
    words_1.append(keys)
    
print(words_1)
# Out:
# ['The', 'spyware', 'attack', 'on', 'WhatsApp', 'users', 'targeted', 'over', 'dozen', 'civil', 'rights', 'activists', 'lawyers', 'journalists', 'Maharashtra', 'Chhattisgarh', 'Goa', 'connected', 'Bhima', 'Koregaon', 'Elgar', 'Parishad', 'cases', 'would', 'be', 'approaching', 'court', 'for', 'action', 'while', 'Nationalist', 'Congress', 'Party', 'demanded', 'Governor', 'Bhagat', 'Singh', 'Koshyari', 'institute', 'probe', 'Among', 'individuals', 'are', 'lawyer', 'Nihalsing', 'Rathod', 'academic', 'Anand', 'Teltumbde', 'activist', 'Kabir', 'Kala', 'Manch', 'Rupali', 'Jadhav', 'Dalit', 'Vivek', 'Sundara', 'former', 'Ph', 'D', 'student', 'Tata', 'Institute', 'Social', 'Sciences', 'TISS', 'Ajmal', 'Khan', 'human', 'Jagdish', 'Meshram', 'Veera', 'Sathidar', 'who', 'also', 'acted', 'film', 'Court', 'Senior', 'officials', 'from', 'Home', 'Department', 'government', 'not', 'know', 'any', 'activity', 'involving', 'private', 'or', 'organisations', 'snooping', 'state', 'process', 'phone', 'tapping
# ...

# %%
from nltk.corpus import stopwords
words_1_clean = []
stopWords = set(stopwords.words('english'))
for words in words_1:
    if words not in stopWords:
        words_1_clean.append(words)
        
print(words_1_clean)
# Out:
# ['The', 'spyware', 'attack', 'WhatsApp', 'users', 'targeted', 'dozen', 'civil', 'rights', 'activists', 'lawyers', 'journalists', 'Maharashtra', 'Chhattisgarh', 'Goa', 'connected', 'Bhima', 'Koregaon', 'Elgar', 'Parishad', 'cases', 'would', 'approaching', 'court', 'action', 'Nationalist', 'Congress', 'Party', 'demanded', 'Governor', 'Bhagat', 'Singh', 'Koshyari', 'institute', 'probe', 'Among', 'individuals', 'lawyer', 'Nihalsing', 'Rathod', 'academic', 'Anand', 'Teltumbde', 'activist', 'Kabir', 'Kala', 'Manch', 'Rupali', 'Jadhav', 'Dalit', 'Vivek', 'Sundara', 'former', 'Ph', 'D', 'student', 'Tata', 'Institute', 'Social', 'Sciences', 'TISS', 'Ajmal', 'Khan', 'human', 'Jagdish', 'Meshram', 'Veera', 'Sathidar', 'also', 'acted', 'film', 'Court', 'Senior', 'officials', 'Home', 'Department', 'government', 'know', 'activity', 'involving', 'private', 'organisations', 'snooping', 'state', 'process', 'phone', 'tapping', 'carried', 'committee', 'senior', 'procurement', 'international', 'products
# ...
